# %%
from src import *
backtester = Backtest(data_dir="data/decrypted_data", portfolio=Portfolio)
returns = backtester.run()

# %%
import quantstats as qs
import pandas as pd
qs.stats.sharpe(pd.DataFrame(returns))
# Out:
# returns    1.312792
# dtype: float64

# %%
import pandas as pd
pd.DataFrame(returns).cumsum().plot()
# Out:
# <Axes: >
