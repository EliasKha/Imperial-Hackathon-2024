# %%
from src import *
backtester = Backtest(portfolio=Portfolio)
returns = backtester.run()
# Out:
# c:\Users\elias\OneDrive\Bureau\Hackathon\Imperial-Hackathon-2024\src\backtest\backtest.py:35: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   self.fig.show()
# 1/78
# Backtest interrupted.

# %%
returns.cumsum().plot()
# Out:
# <Axes: >

# %%
import quantstats as qs
import pandas as pd
qs.stats.sharpe(pd.DataFrame(returns))
# Out:
# returns    1.867433
# dtype: float64
